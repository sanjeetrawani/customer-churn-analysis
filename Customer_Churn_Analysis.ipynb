# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Churn_Unclean_Project.xlsx')
df
# Out:
#     Customer_ID     Customer_Name  Gender    Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female   35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male    NaN        Delhi      Noida
# 2         C1002       Pooja Singh  Female   42.0           UP     Kanpur
# 3         C1003               NaN    Male   59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora   male    26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...    ...          ...        ...
# 537       C5005        Sneha Jain  Female  115.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female   18.0       Delhi       Noida
# 539       C5007       Vikas Yadav    Male   61.0        Delhi
# 540       C5008       Mohit Arora    Male   45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male   25.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0             58.0             basic          1614.26       93273.08
# 1             36.0           Premium           429.60       15858.60
# 2             13.0             Basic           555.03        6869.39
# 3             55.0          Standard              NaN      101349.10
# 4              6.0           Premium           314.02        1926.12
# ..             ...               ...              ...            ...
# 537            1.0               NaN          1633.64        1707.64
# 538           70.0          Standard          2008.83      140376.10
# 539           57.0             Basic          2196.18      125145.26
# 540           63.0             BASIC          1200.00       75799.15
# 541           30.0             Basic          1341.52            NaN
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 0          One Year            UPI            Fiber          Yes
# 1          Two Year           Cash              DSL          Yes
# 2    Month-to-Month     Debit Card               5G           No
# 3          Two Year            UPI               5G           No
# 4          One Year     Debit Card            Cable          Yes
# ..              ...            ...              ...          ...
# 537        Two Year     Debit Card            Cable           No
# 538  Month-to-Month            UPI              DSL          Yes
# 539        One Year           Cash            Cable          Yes
# 540        Two Year            NaN            Fiber          Yes
# 541  Month-to-Month    Credit Card            Cable           No
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 0               No        Yes    No            12-10-2025
# 1              Yes         No    No            05-03-2026
# 2               No         No   Yes            20-02-2026
# 3               No        Yes    No            07-06-2026
# 4               No         No    No            02-04-2026
# ..             ...        ...   ...                   ...
# 537             No        Yes    No            13-03-2026
# 538             No         No    No            26-12-2025
# 539            Yes        Yes    No            14-01-2025
# 540             No         No    No            28-02-2025
# 541             No        Yes    No            29-11-2025
#
# [542 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            542 non-null    str
#  1   Customer_Name          533 non-null    str
#  2   Gender                 536 non-null    str
#  3   Age                    536 non-null    float64
#  4   State                  531 non-null    str
#  5   City                   539 non-null    str
#  6   Tenure_Months          534 non-null    float64
#  7   Subscription_Type      530 non-null    str
#  8   Monthly_Charges        529 non-null    float64
#  9   Total_Charges          533 non-null    float64
#  10  Contract_Type          538 non-null    str
#  11  Payment_Method         526 non-null    str
#  12  Internet_Service       535 non-null    str
#  13  Tech_Support           530 non-null    str
#  14  Senior_Citizen         534 non-null    str
#  15  Dependents             539 non-null    str
#  16  Churn                  538 non-null    str
#  17  Last_Interaction_Date  539 non-null    str
# dtypes: float64(4), str(14)
# memory usage: 120.0 KB

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  536.000000     534.000000       529.000000     533.000000
# mean    44.399254      36.406367      1335.269206   49745.287336
# std     18.556837      20.669599       715.972838   41644.111657
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       756.570000   18770.290000
# 50%     44.000000      38.000000      1306.800000   40649.600000
# 75%     57.000000      54.000000      1900.650000   75647.400000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            UPI            Fiber          Yes             No
# 1        Two Year           Cash              DSL          Yes            Yes
# 2  Month-to-Month     Debit Card               5G           No             No
# 3        Two Year            UPI               5G           No             No
# 4        One Year     Debit Card            Cable          Yes             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            12-10-2025
# 1         No    No            05-03-2026
# 2         No   Yes            20-02-2026
# 3        Yes    No            07-06-2026
# 4         No    No            02-04-2026

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             9
# Gender                    6
# Age                       6
# State                    11
# City                      3
# Tenure_Months             8
# Subscription_Type        12
# Monthly_Charges          13
# Total_Charges             9
# Contract_Type             4
# Payment_Method           16
# Internet_Service          7
# Tech_Support             12
# Senior_Citizen            8
# Dependents                3
# Churn                     4
# Last_Interaction_Date     3
# dtype: int64

# %%
df.shape
# Out:
# (542, 18)

# %%
df.duplicated(['Customer_ID']).sum()
# Out:
# np.int64(8)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     Customer_ID     Customer_Name  Gender    Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female   35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male    NaN        Delhi      Noida
# 2         C1002       Pooja Singh  Female   42.0           UP     Kanpur
# 3         C1003               NaN    Male   59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora   male    26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...    ...          ...        ...
# 537       C5005        Sneha Jain  Female  115.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female   18.0       Delhi       Noida
# 539       C5007       Vikas Yadav    Male   61.0        Delhi
# 540       C5008       Mohit Arora    Male   45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male   25.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0             58.0             basic          1614.26       93273.08
# 1             36.0           Premium           429.60       15858.60
# 2             13.0             Basic           555.03        6869.39
# 3             55.0          Standard              NaN      101349.10
# 4              6.0           Premium           314.02        1926.12
# ..             ...               ...              ...            ...
# 537            1.0               NaN          1633.64        1707.64
# 538           70.0          Standard          2008.83      140376.10
# 539           57.0             Basic          2196.18      125145.26
# 540           63.0             BASIC          1200.00       75799.15
# 541           30.0             Basic          1341.52            NaN
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 0          One Year            UPI            Fiber          Yes
# 1          Two Year           Cash              DSL          Yes
# 2    Month-to-Month     Debit Card               5G           No
# 3          Two Year            UPI               5G           No
# 4          One Year     Debit Card            Cable          Yes
# ..              ...            ...              ...          ...
# 537        Two Year     Debit Card            Cable           No
# 538  Month-to-Month            UPI              DSL          Yes
# 539        One Year           Cash            Cable          Yes
# 540        Two Year            NaN            Fiber          Yes
# 541  Month-to-Month    Credit Card            Cable           No
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 0               No        Yes    No            12-10-2025
# 1              Yes         No    No            05-03-2026
# 2               No         No   Yes            20-02-2026
# 3               No        Yes    No            07-06-2026
# 4               No         No    No            02-04-2026
# ..             ...        ...   ...                   ...
# 537             No        Yes    No            13-03-2026
# 538             No         No    No            26-12-2025
# 539            Yes        Yes    No            14-01-2025
# 540             No         No    No            28-02-2025
# 541             No        Yes    No            29-11-2025
#
# [535 rows x 18 columns]

# %%
df[df.duplicated(['Customer_ID'])]
# Out:
#     Customer_ID  Customer_Name  Gender   Age    State       City  \
# 524       C1018  Anikta Sharma  Female  41.0  Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 524           48.0           Premium          2328.32      111299.36
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 524  Month-to-Month    Net Banking            Fiber          Yes
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 524             No        Yes    No            04-06-2025

# %%
df.drop(524,inplace=True)

# %%
df.duplicated(['Customer_ID']).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            UPI            Fiber          Yes             No
# 1        Two Year           Cash              DSL          Yes            Yes
# 2  Month-to-Month     Debit Card               5G           No             No
# 3        Two Year            UPI               5G           No             No
# 4        One Year     Debit Card            Cable          Yes             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            12-10-2025
# 1         No    No            05-03-2026
# 2         No   Yes            20-02-2026
# 3        Yes    No            07-06-2026
# 4         No    No            02-04-2026

# %%
df.shape
# Out:
# (534, 18)

# %%
df.replace(['N/A','NULL','',' '],np.nan,inplace=True)
# Out:
#     Customer_ID     Customer_Name  Gender    Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female   35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male    NaN        Delhi      Noida
# 2         C1002       Pooja Singh  Female   42.0           UP     Kanpur
# 3         C1003               NaN    Male   59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora   male    26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...    ...          ...        ...
# 537       C5005        Sneha Jain  Female  115.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female   18.0       Delhi       Noida
# 539       C5007       Vikas Yadav    Male   61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male   45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male   25.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0             58.0             basic          1614.26       93273.08
# 1             36.0           Premium           429.60       15858.60
# 2             13.0             Basic           555.03        6869.39
# 3             55.0          Standard              NaN      101349.10
# 4              6.0           Premium           314.02        1926.12
# ..             ...               ...              ...            ...
# 537            1.0               NaN          1633.64        1707.64
# 538           70.0          Standard          2008.83      140376.10
# 539           57.0             Basic          2196.18      125145.26
# 540           63.0             BASIC          1200.00       75799.15
# 541           30.0             Basic          1341.52            NaN
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 0          One Year            UPI            Fiber          Yes
# 1          Two Year           Cash              DSL          Yes
# 2    Month-to-Month     Debit Card               5G           No
# 3          Two Year            UPI               5G           No
# 4          One Year     Debit Card            Cable          Yes
# ..              ...            ...              ...          ...
# 537        Two Year     Debit Card            Cable           No
# 538  Month-to-Month            UPI              DSL          Yes
# 539        One Year           Cash            Cable          Yes
# 540        Two Year            NaN            Fiber          Yes
# 541  Month-to-Month    Credit Card            Cable           No
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 0               No        Yes    No            12-10-2025
# 1              Yes         No    No            05-03-2026
# 2               No         No   Yes            20-02-2026
# 3               No        Yes    No            07-06-2026
# 4               No         No    No            02-04-2026
# ..             ...        ...   ...                   ...
# 537             No        Yes    No            13-03-2026
# 538             No         No    No            26-12-2025
# 539            Yes        Yes    No            14-01-2025
# 540             No         No    No            28-02-2025
# 541             No        Yes    No            29-11-2025
#
# [534 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             8
# Gender                    5
# Age                       6
# State                    10
# City                      5
# Tenure_Months             7
# Subscription_Type        11
# Monthly_Charges          12
# Total_Charges             8
# Contract_Type             3
# Payment_Method           15
# Internet_Service          6
# Tech_Support             11
# Senior_Citizen            7
# Dependents                2
# Churn                     3
# Last_Interaction_Date     2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 534 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            534 non-null    str
#  1   Customer_Name          526 non-null    str
#  2   Gender                 529 non-null    str
#  3   Age                    528 non-null    float64
#  4   State                  524 non-null    str
#  5   City                   529 non-null    str
#  6   Tenure_Months          527 non-null    float64
#  7   Subscription_Type      523 non-null    str
#  8   Monthly_Charges        522 non-null    float64
#  9   Total_Charges          526 non-null    float64
#  10  Contract_Type          531 non-null    str
#  11  Payment_Method         519 non-null    str
#  12  Internet_Service       528 non-null    str
#  13  Tech_Support           523 non-null    str
#  14  Senior_Citizen         527 non-null    str
#  15  Dependents             532 non-null    str
#  16  Churn                  531 non-null    str
#  17  Last_Interaction_Date  532 non-null    str
# dtypes: float64(4), str(14)
# memory usage: 122.3 KB

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype=='str' else x)

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora    male  26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            UPI            Fiber          Yes             No
# 1        Two Year           Cash              DSL          Yes            Yes
# 2  Month-to-Month     Debit Card               5G           No             No
# 3        Two Year            UPI               5G           No             No
# 4        One Year     Debit Card            Cable          Yes             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            12-10-2025
# 1         No    No            05-03-2026
# 2         No   Yes            20-02-2026
# 3        Yes    No            07-06-2026
# 4         No    No            02-04-2026

# %%
df['Subscription_Type'].value_counts()
# Out:
# Subscription_Type
# Premium     183
# Standard    169
# Basic       167
# basic         2
# BASIC         2
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State    City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra    Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi   Noida
# 2       C1002       Pooja Singh  Female  42.0           UP  Kanpur
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            UPI            Fiber          Yes             No
# 1        Two Year           Cash              DSL          Yes            Yes
# 2  Month-to-Month     Debit Card               5G           No             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            12-10-2025
# 1         No    No            05-03-2026
# 2         No   Yes            20-02-2026

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Debit Card     110
# UPI            109
# Cash           103
# Credit Card     99
# Net Banking     98
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     269
# Yes    263
# Name: count, dtype: int64

# %%
df['Internet_Service'].value_counts()
# Out:
# Internet_Service
# Fiber    140
# Cable    133
# DSL      129
# 5G       126
# Name: count, dtype: int64

# %%
df['Senior_Citizen'].value_counts()
# Out:
# Senior_Citizen
# No     424
# Yes    103
# Name: count, dtype: int64

# %%
df['Senior_Citizen'].value_counts()
# Out:
# Senior_Citizen
# No     424
# Yes    103
# Name: count, dtype: int64

# %%
df['Customer_Name'] = df['Customer_Name'].str.title()
df['State'] = df['State'].str.title()
df['City'] = df['City'].str.title()
df['Subscription_Type'] = df['Subscription_Type'].str.title()
df['Contract_Type'] = df['Contract_Type'].str.title()

# %%
df['Subscription_Type'].value_counts()
# Out:
# Subscription_Type
# Premium     183
# Basic       171
# Standard    169
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     404
# Yes    125
# YES      1
# yes      1
# Name: count, dtype: int64

# %%
df['Churn'] = df['Churn'].str.title()

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     404
# Yes    127
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 534 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            534 non-null    str
#  1   Customer_Name          526 non-null    str
#  2   Gender                 529 non-null    str
#  3   Age                    528 non-null    float64
#  4   State                  524 non-null    str
#  5   City                   529 non-null    str
#  6   Tenure_Months          527 non-null    float64
#  7   Subscription_Type      523 non-null    str
#  8   Monthly_Charges        522 non-null    float64
#  9   Total_Charges          526 non-null    float64
#  10  Contract_Type          531 non-null    str
#  11  Payment_Method         519 non-null    str
#  12  Internet_Service       528 non-null    str
#  13  Tech_Support           523 non-null    str
#  14  Senior_Citizen         527 non-null    str
#  15  Dependents             532 non-null    str
#  16  Churn                  531 non-null    str
#  17  Last_Interaction_Date  532 non-null    str
# dtypes: float64(4), str(14)
# memory usage: 122.3 KB

# %%
# df = df.apply(lambda x: x.str.strip() if x.dtype=='str' else x)

df = df.apply(lambda x: x.str.title() if x.dtype=='str' else x)
df
# Out:
#     Customer_ID     Customer_Name  Gender    Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female   35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male    NaN        Delhi      Noida
# 2         C1002       Pooja Singh  Female   42.0           Up     Kanpur
# 3         C1003               NaN    Male   59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora    Male   26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...    ...          ...        ...
# 537       C5005        Sneha Jain  Female  115.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female   18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male   61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male   45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male   25.0           Up     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0             58.0             Basic          1614.26       93273.08
# 1             36.0           Premium           429.60       15858.60
# 2             13.0             Basic           555.03        6869.39
# 3             55.0          Standard              NaN      101349.10
# 4              6.0           Premium           314.02        1926.12
# ..             ...               ...              ...            ...
# 537            1.0               NaN          1633.64        1707.64
# 538           70.0          Standard          2008.83      140376.10
# 539           57.0             Basic          2196.18      125145.26
# 540           63.0             Basic          1200.00       75799.15
# 541           30.0             Basic          1341.52            NaN
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 0          One Year            Upi            Fiber          Yes
# 1          Two Year           Cash              Dsl          Yes
# 2    Month-To-Month     Debit Card               5G           No
# 3          Two Year            Upi               5G           No
# 4          One Year     Debit Card            Cable          Yes
# ..              ...            ...              ...          ...
# 537        Two Year     Debit Card            Cable           No
# 538  Month-To-Month            Upi              Dsl          Yes
# 539        One Year           Cash            Cable          Yes
# 540        Two Year            NaN            Fiber          Yes
# 541  Month-To-Month    Credit Card            Cable           No
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 0               No        Yes    No            12-10-2025
# 1              Yes         No    No            05-03-2026
# 2               No         No   Yes            20-02-2026
# 3               No        Yes    No            07-06-2026
# 4               No         No    No            02-04-2026
# ..             ...        ...   ...                   ...
# 537             No        Yes    No            13-03-2026
# 538             No         No    No            26-12-2025
# 539            Yes        Yes    No            14-01-2025
# 540             No         No    No            28-02-2025
# 541             No        Yes    No            29-11-2025
#
# [534 rows x 18 columns]

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    269
# Male      260
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             8
# Gender                    5
# Age                       6
# State                    10
# City                      5
# Tenure_Months             7
# Subscription_Type        11
# Monthly_Charges          12
# Total_Charges             8
# Contract_Type             3
# Payment_Method           15
# Internet_Service          6
# Tech_Support             11
# Senior_Citizen            7
# Dependents                2
# Churn                     3
# Last_Interaction_Date     2
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  528.000000     527.000000       522.000000     526.000000
# mean    44.335227      36.497154      1328.054732   49622.650285
# std     18.652503      20.672889       712.791278   41586.449512
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       756.995000   18794.280000
# 50%     44.000000      38.000000      1295.855000   40299.800000
# 75%     57.000000      54.000000      1877.910000   74535.230000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
df = df[(df['Age'] >= 18) & (df['Age'] <=100)]

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  518.000000     511.000000       507.000000     510.000000
# mean    43.405405      36.389432      1329.300454   50072.877608
# std     15.495233      20.553589       717.018414   41214.574538
# min     18.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       757.420000   18928.310000
# 50%     43.000000      38.000000      1294.600000   40737.755000
# 75%     56.750000      54.000000      1879.020000   74535.230000
# max     70.000000      72.000000      2492.510000  171429.830000

# %%
df = df[df['Monthly_Charges'] >=0]

df = df[df['Total_Charges'] >=0]

# %%
df
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2         C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4         C1004       Mohit Arora    Male  26.0      Gujarat  Ahmedabad
# 6         C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7         C1007       Vikas Yadav    Male  61.0        Delhi        NaN
# ..          ...               ...     ...   ...          ...        ...
# 534       C5002       Pooja Singh  Female  42.0           Up     Kanpur
# 536       C5004       Mohit Arora    Male  26.0      Gujarat  Ahmedabad
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi        NaN
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0             58.0             Basic          1614.26       93273.08
# 2             13.0             Basic           555.03        6869.39
# 4              6.0           Premium           314.02        1926.12
# 6             70.0          Standard          2008.83      140376.10
# 7             57.0             Basic          2196.18      125145.26
# ..             ...               ...              ...            ...
# 534           13.0             Basic           555.03        6869.39
# 536            6.0           Premium           314.02        1926.12
# 538           70.0          Standard          2008.83      140376.10
# 539           57.0             Basic          2196.18      125145.26
# 540           63.0             Basic          1200.00       75799.15
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 0          One Year            Upi            Fiber          Yes
# 2    Month-To-Month     Debit Card               5G           No
# 4          One Year     Debit Card            Cable          Yes
# 6    Month-To-Month            Upi              Dsl          Yes
# 7          One Year           Cash            Cable          Yes
# ..              ...            ...              ...          ...
# 534  Month-To-Month     Debit Card               5G           No
# 536        One Year     Debit Card            Cable          Yes
# 538  Month-To-Month            Upi              Dsl          Yes
# 539        One Year           Cash            Cable          Yes
# 540        Two Year            NaN            Fiber          Yes
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 0               No        Yes    No            12-10-2025
# 2               No         No   Yes            20-02-2026
# 4               No         No    No            02-04-2026
# 6               No         No    No            26-12-2025
# 7              Yes        Yes    No            14-01-2025
# ..             ...        ...   ...                   ...
# 534             No         No   Yes            20-02-2026
# 536             No         No    No            02-04-2026
# 538             No         No    No            26-12-2025
# 539            Yes        Yes    No            14-01-2025
# 540             No         No    No            28-02-2025
#
# [491 rows x 18 columns]

# %%
df['Last_Interaction_Date'] = pd.to_datetime(df['Last_Interaction_Date'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# Customer_ID                0
# Customer_Name              5
# Gender                     4
# Age                        0
# State                      7
# City                       5
# Tenure_Months              5
# Subscription_Type          6
# Monthly_Charges            0
# Total_Charges              0
# Contract_Type              2
# Payment_Method            15
# Internet_Service           6
# Tech_Support               9
# Senior_Citizen             6
# Dependents                 1
# Churn                      2
# Last_Interaction_Date    314
# dtype: int64

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2       C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4       C1004       Mohit Arora    Male  26.0      Gujarat  Ahmedabad
# 6       C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7       C1007       Vikas Yadav    Male  61.0        Delhi        NaN
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             Basic          1614.26       93273.08
# 2           13.0             Basic           555.03        6869.39
# 4            6.0           Premium           314.02        1926.12
# 6           70.0          Standard          2008.83      140376.10
# 7           57.0             Basic          2196.18      125145.26
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            Upi            Fiber          Yes             No
# 2  Month-To-Month     Debit Card               5G           No             No
# 4        One Year     Debit Card            Cable          Yes             No
# 6  Month-To-Month            Upi              Dsl          Yes             No
# 7        One Year           Cash            Cable          Yes            Yes
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            2025-12-10
# 2         No   Yes                   NaT
# 4         No    No            2026-02-04
# 6         No    No                   NaT
# 7        Yes    No                   NaT

# %%
df['Tech_Support'] = df['Tech_Support'].fillna('No')

df['Payment_Method'] = df['Payment_Method'].fillna('Unknown')

df['Monthly_Charges'] = df['Monthly_Charges'].fillna(df['Monthly_Charges'].mean())

df['Total_Charges'] = df['Total_Charges'].fillna(df['Total_Charges'].mean())

df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# Customer_ID                0
# Customer_Name              5
# Gender                     4
# Age                        0
# State                      7
# City                       5
# Tenure_Months              5
# Subscription_Type          6
# Monthly_Charges            0
# Total_Charges              0
# Contract_Type              2
# Payment_Method             0
# Internet_Service           6
# Tech_Support               0
# Senior_Citizen             6
# Dependents                 1
# Churn                      2
# Last_Interaction_Date    314
# dtype: int64

# %%
df.head(2)
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State    City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra    Pune
# 2       C1002       Pooja Singh  Female  42.0           Up  Kanpur
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             Basic          1614.26       93273.08
# 2           13.0             Basic           555.03        6869.39
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# 0        One Year            Upi            Fiber          Yes             No
# 2  Month-To-Month     Debit Card               5G           No             No
#
#   Dependents Churn Last_Interaction_Date
# 0        Yes    No            2025-12-10
# 2         No   Yes                   NaT

# %%
# Customer lifytime value

df['Customer_Value'] = df['Monthly_Charges']*df['Tenure_Months']

# %%
df['Monthly_Revenue'] = df['Monthly_Charges']

# %%
df['Senior_Flag'] = np.where(df['Age'] >=60,'Senior','Adult')

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 2       C1002       Pooja Singh  Female  42.0           Up     Kanpur
# 4       C1004       Mohit Arora    Male  26.0      Gujarat  Ahmedabad
# 6       C1006        Neha Verma  Female  18.0        Delhi      Noida
# 7       C1007       Vikas Yadav    Male  61.0        Delhi        NaN
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  ...  \
# 0           58.0             Basic          1614.26       93273.08  ...
# 2           13.0             Basic           555.03        6869.39  ...
# 4            6.0           Premium           314.02        1926.12  ...
# 6           70.0          Standard          2008.83      140376.10  ...
# 7           57.0             Basic          2196.18      125145.26  ...
#
#   Payment_Method Internet_Service Tech_Support Senior_Citizen Dependents  \
# 0            Upi            Fiber          Yes             No        Yes
# 2     Debit Card               5G           No             No         No
# 4     Debit Card            Cable          Yes             No         No
# 6            Upi              Dsl          Yes             No         No
# 7           Cash            Cable          Yes            Yes        Yes
#
#   Churn Last_Interaction_Date Customer_Value  Monthly_Revenue  Senior_Flag
# 0    No            2025-12-10       93627.08          1614.26        Adult
# 2   Yes                   NaT        7215.39           555.03        Adult
# 4    No            2026-02-04        1884.12           314.02        Adult
# 6    No                   NaT      140618.10          2008.83        Adult
# 7    No                   NaT      125182.26          2196.18       Senior
#
# [5 rows x 21 columns]

# %%
# Churn flag

df['Churn_Flag'] = df['Churn'].map({'Yes':1,'No':0})

# %%
bins = [0,12,24,48,72]

label = labels = ['0-12 month','13-24 month','25-48 month','49-72 month']

df['Tenure_Group'] = pd.cut(df['Tenure_Months'],bins=bins,labels=label)

# %%
df['Last_Interaction_Date'] = df['Last_Interaction_Date'].fillna(df['Last_Interaction_Date'].median())

# %%
df.shape
# Out:
# (491, 23)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 491 entries, 0 to 540
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            491 non-null    str
#  1   Customer_Name          486 non-null    str
#  2   Gender                 487 non-null    str
#  3   Age                    491 non-null    float64
#  4   State                  484 non-null    str
#  5   City                   486 non-null    str
#  6   Tenure_Months          486 non-null    float64
#  7   Subscription_Type      485 non-null    str
#  8   Monthly_Charges        491 non-null    float64
#  9   Total_Charges          491 non-null    float64
#  10  Contract_Type          489 non-null    str
#  11  Payment_Method         491 non-null    str
#  12  Internet_Service       485 non-null    str
#  13  Tech_Support           491 non-null    str
#  14  Senior_Citizen         485 non-null    str
#  15  Dependents             490 non-null    str
#  16  Churn                  489 non-null    str
#  17  Last_Interaction_Date  491 non-null    datetime64[us]
#  18  Customer_Value         486 non-null    float64
#  19  Monthly_Revenue        491 non-null    float64
#  20  Senior_Flag            491 non-null    str
#  21  Churn_Flag             489 non-null    float64
#  22  Tenure_Group           486 non-null    category
# dtypes: category(1), datetime64[us](1), float64(7), str(14)
# memory usage: 126.1 KB

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges  \
# count  491.000000     486.000000       491.000000     491.000000
# mean    43.195519      36.034979      1357.248310   50239.882933
# min     18.000000       1.000000       302.540000     354.120000
# 25%     30.000000      19.000000       762.910000   19088.300000
# 50%     43.000000      38.000000      1306.800000   40649.600000
# 75%     56.000000      53.000000      1882.895000   73712.710000
# max     70.000000      72.000000      2492.510000  171429.830000
# std     15.417008      20.479027       652.328938   39705.180915
#
#             Last_Interaction_Date  Customer_Value  Monthly_Revenue  Churn_Flag
# count                         491      486.000000       491.000000  489.000000
# mean   2025-09-14 04:09:17.230142    50175.936708      1357.248310    0.237219
# min           2025-01-01 00:00:00      379.700000       302.540000    0.000000
# 25%           2025-09-06 00:00:00    19108.912500       762.910000    0.000000
# 50%           2025-09-06 00:00:00    40701.195000      1306.800000    0.000000
# 75%           2025-09-06 00:00:00    73757.105000      1882.895000    0.000000
# max           2026-12-06 00:00:00   171658.830000      2492.510000    1.000000
# std                           NaN    39710.645735       652.328938    0.425813

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Customer_Name            5
# Gender                   4
# Age                      0
# State                    7
# City                     5
# Tenure_Months            5
# Subscription_Type        6
# Monthly_Charges          0
# Total_Charges            0
# Contract_Type            2
# Payment_Method           0
# Internet_Service         6
# Tech_Support             0
# Senior_Citizen           6
# Dependents               1
# Churn                    2
# Last_Interaction_Date    0
# Customer_Value           5
# Monthly_Revenue          0
# Senior_Flag              0
# Churn_Flag               2
# Tenure_Group             5
# dtype: int64

# %%
df['Churn_Flag'].value_counts()
# Out:
# Churn_Flag
# 0.0    373
# 1.0    116
# Name: count, dtype: int64

# %%
# Export


df.to_csv('Clean_Churn_Data.csv',index=False)

# %%
# Export into MySql

from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:@localhost:3306/churn_db"
)

# %%
engine = create_engine(
    "mysql+pymysql://root:Sanjeet%409973@localhost:3306/churn_db"
)

# %%
with engine.connect() as connection:
    print("MySQL Connected Successfully!")
# Out:
# MySQL Connected Successfully!

# %%
df.to_sql(
    "customer_churn",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 491
